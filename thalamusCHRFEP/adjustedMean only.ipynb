# %%
import pandas as pd
pd.set_option('max_row',5000)
pd.set_option('max_colum',5000)

# %load_ext rmagic

# %R require(ggplot2)
# %R require(ppcor)
# %R require(car)
# %R require(multcomp)
# %R require(effects)
# Out:
# Loading required package: ggplot2
# Loading required package: ppcor
# Loading required package: car
# Loading required package: MASS
# Loading required package: nnet
# Loading required package: multcomp
# Loading required package: mvtnorm
# Loading required package: survival
# Loading required package: splines
# Loading required package: TH.data
# Loading required package: effects
# Loading required package: lattice
# Loading required package: grid
# Loading required package: colorspace
#
# Attaching package: ‘effects’
#
# The following object is masked from ‘package:car’:
#
#     Prestige
#
# The following object is masked from ‘package:datasets’:
#
#     Titanic

# %%
allData=pd.read_csv("/Users/admin/Dropbox/CHRvsNOR/2014_stats/37_38_22_thr10/LR_averaged_thalData.csv",sep='\t')
allData.columns=[u'subject', u'group', u'cortex', u'intracranialVolume', u'cortexVolume', u'relativeConnectivity', u'segmentVolume', u'thalamusVolume', u'totalConnectivity', u'sex', u'age', u'bday', u'education', u'hand', u'IQ', u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'PSP10', u'PSP20', u'PSP30', u'PSP40', u'PSP50', u'PSN10', u'PSN20', u'PSN30', u'PSN40', u'PSN50', u'PSN60', u'PSD10', u'PSD20', u'PSD30', u'PSD40', u'PSG10', u'PSG20', u'PSG30', u'PSG40', u'PSPTOT0', u'PSNTOT0', u'PSDTOT0', u'PSGTOT0', u'SIPSTOT0', u'AS1_10', u'AS1_20', u'AS1_30', u'AS1_40', u'AS2_10', u'AS2_20', u'AS3_10', u'AS3_20', u'AS3_30', u'AS4_10', u'AS4_20', u'AS4_30', u'AS5_10', u'AS5_20', u'AS5_30', u'AS5_40', u'AS6_10', u'AS6_20', u'AS6_30', u'AS6_40', u'AS7_10', u'AS7_20', u'AS7_30', u'AS7_40', u'AS7_50', u'AS7_60', u'AS7_70', u'AS7_80', u'AS1TOT0', u'AS2TOT0', u'AS3TOT0', u'AS4TOT0', u'AS5TOT0', u'AS6TOT0', u'AS7TOT0', u'CAARMSTOT0', u'SAPS_ghksrkr0', u'SAPS_akdtkd0', u'SAPS_rhldlgksgodehd0', u'SAPS_didtjdwjrtkrh0', u'SAPStot0', u'SANS_wjdehdensak0', u'SANS_akfdjqtdma0', u'SANS_andmldyr0', u'SANS_anzhorka0', u'SANS_wndmlfur0', u'SANStot0', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0', u'parentalSES', u'panssTot', u'pTot', u'nTot', u'gTot']

# %%
for CORTEX in ['OFC','PC']:
    print CORTEX
    df = allData[allData.cortex==CORTEX]
   
    # %R -i df
    # %R df <- as.data.frame(df)
    # %R groups=c("UHR","HCs","FEP")

    #Anova
    # %R anovaOutput <- aov(relativeConnectivity ~ group, data=df)

    #Adjusted means
    # %R adjustedMeans <- effect("group", anovaOutput, se=TRUE)

    #Adjusted mean and confidence intervals calculation
    # %R adjustedMean=c(adjustedMeans$fit[1],adjustedMeans$fit[2],adjustedMeans$fit[3])
    
    # %R adjustedMeanLCI=c(adjustedMeans$lower[1],adjustedMeans$lower[2],adjustedMeans$lower[3])
    
    # %R adjustedMeanUCI=c(adjustedMeans$upper[1],adjustedMeans$upper[2],adjustedMeans$upper[3])

    #Dataframe for graph
    # %R forGraph=data.frame(adjustedMean,adjustedMeanLCI,adjustedMeanUCI,group=groups)

    #Order groups
    # %R forGraph$group <- factor(forGraph$group, levels=c("HCs","UHR","FEP"), ordered=TRUE)
    # %R -o adjustedMean
    # %R -o adjustedMeanLCI
    # %R -o adjustedMeanUCI
    
    toPrint = pd.DataFrame.from_dict({'CHR':[adjustedMean[0],adjustedMeanUCI[0],adjustedMeanLCI[0]],
                                      'HCs':[adjustedMean[1],adjustedMeanUCI[1],adjustedMeanLCI[1]],
                                      'FEP':[adjustedMean[2],adjustedMeanUCI[2],adjustedMeanLCI[2]]},
                                     orient='index')
    
    toPrint.columns = ['adjusted Mean', 'upper confidence interval', 'lower confidence interval']
    display(toPrint)
# Out:
# OFC
#      adjusted Mean  upper confidence interval  lower confidence interval
# HCs       0.086603                   0.095122                   0.078085
# CHR       0.072670                   0.081075                   0.064264
# FEP       0.060205                   0.071252                   0.049158
# PC
#      adjusted Mean  upper confidence interval  lower confidence interval
# HCs       0.147485                   0.166592                   0.128378
# CHR       0.168689                   0.187543                   0.149835
# FEP       0.187517                   0.212296                   0.162738

# %%
df = allData[allData.group=='CHR'].groupby('cortex').get_group('OFC')[['subject','group','totalConnectivity','GAF']]
df.columns=['subject','group','number of tractography count','GAF score']
df
# Out:
#        subject group  number of tractography count  GAF score
# 5    CHR02_JHJ   CHR                 976199.500417         38
# 13   CHR04_PJH   CHR                1687768.999080         58
# 21   CHR05_SJH   CHR                2244155.000850         45
# 29   CHR06_JHJ   CHR                1511807.000250         47
# 37   CHR08_PJH   CHR                2336888.500250         51
# 45   CHR10_LJJ   CHR                1567909.498460         44
# 53   CHR12_LSH   CHR                2103562.499580         54
# 61   CHR14_KKS   CHR                1110585.000230         44
# 69   CHR16_KHJ   CHR                2044109.501010         45
# 77   CHR18_LYM   CHR                1720721.499920         58
# 85   CHR21_HET   CHR                1866792.999430         43
# 93   CHR22_PSJ   CHR                2428598.998970         53
# 101  CHR24_MJW   CHR                2175481.498330         53
# 109  CHR25_KYS   CHR                1450192.499980         47
# 117  CHR26_SYK   CHR                2311454.002240         53
# 125  CHR27_JTM   CHR                1887785.998640         53
# 133  CHR28_KTH   CHR                1155940.499140         47
# 141  CHR30_OSJ   CHR                1033040.500010         55
# 149  CHR31_SHB   CHR                1851459.999530         45
# 157  CHR34_HHJ   CHR                 964254.998962         55
# 165  CHR35_JSS   CHR                1076054.499950         43
# 173  CHR36_KJH   CHR                1344759.000690         53
# 181  CHR38_KJC   CHR                1432594.999950         55
# 189  CHR39_LKB   CHR                1876300.500680         55
# 197  CHR40_LSH   CHR                 802634.000922         43
# 205  CHR41_SSA   CHR                1276792.499500         57
# 213  CHR43_HSW   CHR                 697411.500142         33
# 221  CHR45_JYS   CHR                 925535.500271         41
# 229  CHR46_SKH   CHR                1082516.000820         50
# 237  CHR47_SDI   CHR                1453662.001660         67
# 245  CHR48_KSY   CHR                 299474.499343         37
# 253  CHR49_LHY   CHR                2474818.499190         55
# 261  CHR50_JHI   CHR                1983439.500460         49
# 269  CHR51_KMR   CHR                 630822.000141         41
# 277  CHR53_PSS   CHR                 927522.999115         53
# 285  CHR54_PSC   CHR                1381319.999580         43
# 293  CHR55_KJB   CHR                 881454.000079         53
# 301  CHR57_YWY   CHR                 821516.500537         60
