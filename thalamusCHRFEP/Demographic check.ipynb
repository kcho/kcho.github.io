# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import os
import re
import scipy.stats
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows',5000)
pd.set_option('display.max_columns',500)

# %% [markdown]
# #Data from thalamus project only

# %%
demoTable=pd.read_csv("/Users/admin/Dropbox/CHRvsNOR/2014_stats/37_38_22_thr10/demoTable.csv", sep='\t')

# %%
demoTable
# Out:
#       subject group_x   IQ  hand  education  age  sex  parentalSES SEX
# 0   CHR02_JHJ     CHR  118     1         12   18    1            2   M
# 1   CHR04_PJH     CHR  118     1         15   24    1            3   M
# 2   CHR05_SJH     CHR  120     1         16   27    1            2   M
# 3   CHR06_JHJ     CHR  116     1         13   19    2            2   F
# 4   CHR08_PJH     CHR  136     1         14   21    2            2   F
# 5   CHR10_LJJ     CHR  116     1         13   18    1            4   M
# 6   CHR12_LSH     CHR   98     1         13   20    1            5   M
# 7   CHR14_KKS     CHR   84     1         12   20    2            4   F
# 8   CHR16_KHJ     CHR  101     1         12   18    1            5   M
# 9   CHR18_LYM     CHR  117     1         15   25    2            4   F
# 10  CHR21_HET     CHR  107     1         13   23    1            3   M
# 11  CHR22_PSJ     CHR  130     1         13   19    1            3   M
# ...

# %%
demoTable.groupby('group_x').count()
# Out:
#          subject  group_x  IQ  hand  education  age  sex  parentalSES  SEX
# group_x
# CHR           38       38  38    38         38   38   38           38   38
# CON           37       37  37    37         37   37   37           37   37
# FEP           22       22  21    22         22   22   22           22   22

# %%
IQ=demoTable.IQ
AGE = demoTable.age
EDU = demoTable.education
SES = demoTable.parentalSES
GROUP = demoTable.group_x

formula = 'IQ ~ GROUP'
lm = ols(formula, demoTable).fit()
print 'IQ~GROUP'
print '========='
print anova_lm(lm)
#print lm.summary()
print '\n\n\n'

formula = 'AGE ~ GROUP'
lm = ols(formula, demoTable).fit()
print 'AGE ~ GROUP'
print '==========='
print anova_lm(lm)
#print lm.summary()
print '\n\n\n'


formula = 'EDU ~ GROUP'
lm = ols(formula, demoTable).fit()
print 'EDU ~ GROUP'
print '==========='
print anova_lm(lm)
#print lm.summary()
print '\n\n\n'


formula = 'SES ~ GROUP'
lm = ols(formula, demoTable).fit()
print 'SES ~ GROUP'
print '==========='
print anova_lm(lm)
#print lm.summary()
print '\n\n\n'
# Out:
# IQ~GROUP
# ...
#           df        sum_sq     mean_sq        F    PR(>F)
# GROUP      2    745.500237  372.750119  2.68772  0.073321
# Residual  93  12897.833096  138.686377      NaN       NaN
#
#
#
#
# AGE ~ GROUP
# ...
#           df      sum_sq    mean_sq        F    PR(>F)
# GROUP      2   21.353875  10.676938  1.37603  0.257619
# Residual  94  729.367774   7.759232      NaN       NaN
#
#
#
#
# EDU ~ GROUP
# ...
#           df      sum_sq   mean_sq         F    PR(>F)
# GROUP      2    1.607174  0.803587  0.428032  0.653054
# Residual  94  176.475301  1.877397       NaN       NaN
#
#
#
#
# SES ~ GROUP
# ...
#           df     sum_sq   mean_sq         F    PR(>F)
# GROUP      2   0.991454  0.495727  0.593662  0.554358
# Residual  94  78.493082  0.835033       NaN       NaN

# %% [markdown]
# - R script for 3-sample test for equality of proportions without continuity correction
# - Run below script in R

# %%
prop.test(table(table$group,table$hand),correct=FALSE)


> prop.test(table(table$group,table$hand),correct=FALSE)

	3-sample test for equality of proportions without continuity correction

data:  table(table$group, table$hand)
X-squared = 0.6602, df = 2, p-value = 0.7189
alternative hypothesis: two.sided
sample estimates:
   prop 1    prop 2    prop 3 
0.9189189 0.8947368 0.9545455 

Warning message:
In prop.test(table(table$group, table$hand), correct = FALSE) :
  Chi-squared approximation may be incorrect
> 
> prop.test(table(table$group,table$sex),correct=FALSE)

	3-sample test for equality of proportions without continuity correction

data:  table(table$group, table$sex)
X-squared = 4.5264, df = 2, p-value = 0.104
alternative hypothesis: two.sided
sample estimates:
   prop 1    prop 2    prop 3 
0.6216216 0.6842105 0.4090909

# %% [markdown]
# ### Demographic table make up

# %%
demoTable.groupby('group_x').mean().to_excel("/Users/admin/Dropbox/CHRvsNOR/2014_stats/37_38_22_thr10/demo_mean.xlsx",'Sheet1')

# %%
demoTable.groupby('group_x').std().to_excel("/Users/admin/Dropbox/CHRvsNOR/2014_stats/37_38_22_thr10/demo_std.xlsx",'Sheet1')

# %%
allData=pd.read_csv("/Users/admin/Dropbox/CHRvsNOR/2014_stats/37_38_22_thr10/LR_averaged_thalData.csv",sep='\t')
allData.columns=[u'subject', u'group', u'cortex', u'intracranialVolume', u'cortexVolume', u'relativeConnectivity', u'segmentVolume', u'thalamusVolume', u'totalConnectivity', u'sex', u'age', u'bday', u'education', u'hand', u'IQ', u'P1', u'P2', u'P3', u'P4', u'P5', u'P6', u'P7', u'N1', u'N2', u'N3', u'N4', u'N5', u'N6', u'N7', u'G1', u'G2', u'G3', u'G4', u'G5', u'G6', u'G7', u'G8', u'G9', u'G10', u'G11', u'G12', u'G13', u'G14', u'G15', u'G16', u'PSP10', u'PSP20', u'PSP30', u'PSP40', u'PSP50', u'PSN10', u'PSN20', u'PSN30', u'PSN40', u'PSN50', u'PSN60', u'PSD10', u'PSD20', u'PSD30', u'PSD40', u'PSG10', u'PSG20', u'PSG30', u'PSG40', u'PSPTOT0', u'PSNTOT0', u'PSDTOT0', u'PSGTOT0', u'SIPSTOT0', u'AS1_10', u'AS1_20', u'AS1_30', u'AS1_40', u'AS2_10', u'AS2_20', u'AS3_10', u'AS3_20', u'AS3_30', u'AS4_10', u'AS4_20', u'AS4_30', u'AS5_10', u'AS5_20', u'AS5_30', u'AS5_40', u'AS6_10', u'AS6_20', u'AS6_30', u'AS6_40', u'AS7_10', u'AS7_20', u'AS7_30', u'AS7_40', u'AS7_50', u'AS7_60', u'AS7_70', u'AS7_80', u'AS1TOT0', u'AS2TOT0', u'AS3TOT0', u'AS4TOT0', u'AS5TOT0', u'AS6TOT0', u'AS7TOT0', u'CAARMSTOT0', u'SAPS_ghksrkr0', u'SAPS_akdtkd0', u'SAPS_rhldlgksgodehd0', u'SAPS_didtjdwjrtkrh0', u'SAPStot0', u'SANS_wjdehdensak0', u'SANS_akfdjqtdma0', u'SANS_andmldyr0', u'SANS_anzhorka0', u'SANS_wndmlfur0', u'SANStot0', u'GAF', u'GAFpastyr0', u'GAFpremorbid0', u'SOFASpresent0', u'SOFASpastyr0', u'SOFASpremorbid0', u'HAMA0', u'HAMD', u'YMS', u'BPRS0', u'parentalSES', u'panssTot', u'pTot', u'nTot', u'gTot']
allData = allData[allData.cortex=='LPFC']

# %%
norData = allData[allData.group=='CON']
chrData = allData[allData.group=='CHR']
fepData = allData[allData.group=='FEP']

# %% [markdown]
# ### Sex count

# %%
norData.groupby('sex').count()['subject']
# Out:
# sex
# 1      23
# 2      14
# Name: subject, dtype: int64

# %%
chrData.groupby('sex').count()['subject']
# Out:
# sex
# 1      26
# 2      12
# Name: subject, dtype: int64

# %%
fepData.groupby('sex').count()['subject']
# Out:
# sex
# 1       9
# 2      13
# Name: subject, dtype: int64

# %%
norData.groupby('hand').count()['subject']
# Out:
# hand
# 1       34
# 2        3
# Name: subject, dtype: int64

# %%
chrData.groupby('hand').count()['subject']
# Out:
# hand
# 1       34
# 2        4
# Name: subject, dtype: int64

# %%
fepData.groupby('hand').count()['subject']
# Out:
# hand
# 1       21
# 2        1
# Name: subject, dtype: int64

# %%
chrPANSS = chrData.pTot + chrData.nTot + chrData.gTot
print chrPANSS.mean()
print chrPANSS.std()
print
print chrData.pTot.mean()
print chrData.pTot.std()
print

print chrData.nTot.mean()
print chrData.nTot.std()
print

print chrData.gTot.mean()
print chrData.gTot.std()
# Out:
# 63.7368421053
# 14.0821608648
#
# 13.5
# 3.28592411618
#
# 16.7631578947
# 5.55772756656
#
# 33.4736842105
# 8.51623835913

# %%
fepPANSS = fepData.pTot + fepData.nTot + fepData.gTot
print fepPANSS.mean()
print fepPANSS.std()
print

print fepData.pTot.mean()
print fepData.pTot.std()
print

print fepData.nTot.mean()
print fepData.nTot.std()
print

print fepData.gTot.mean()
print fepData.gTot.std()
# Out:
# 66.9090909091
# 12.4820217033
#
# 15.3636363636
# 5.13202322069
#
# 16.8181818182
# 5.79520625901
#
# 34.7272727273
# 6.28817346621

# %%
for df in chrData, fepData:
    print df.group.unique()
    print 'GAF mean'
    print df.GAF.mean()
    print 'GAF std'
    print df.GAF.std()
    print
# Out:
# ['CHR']
# GAF mean
# 49.3684210526
# GAF std
# 7.14869503356
#
# ['FEP']
# GAF mean
# 49.0
# GAF std
# 11.771636614
